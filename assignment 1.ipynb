# %% [markdown]
# Capstone project

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
git remote add origin https://github.com/LuoTY123/Coursera_Capstone.git
git push -u origin master
# Out:
#   File "<ipython-input-6-64bf98749450>", line 1
#     git remote add origin https://github.com/LuoTY123/Coursera_Capstone.git
#              ^
# SyntaxError: invalid syntax
